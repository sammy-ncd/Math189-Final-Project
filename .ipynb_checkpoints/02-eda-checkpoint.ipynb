# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# This notebook explores relationships between Waymo expansion,
# taxi activity, public transit ridership, and airport ground transportation
# in San Francisco from 2023 to 2025.
#
# Research Question:
#
# Did the expansion of Waymo correspond with changes in taxi activity,
# public transit ridership, and the broader transportation market?
